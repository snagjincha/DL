# %% [raw]
# ---
# title: "04wk-1: 퀴즈3"
# author: "차상진"
# date: "01/04/2024"
# draft: false
# ---

# %%
1+1
# Out:
# 2

# %%
2+2
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:55746d11-e898-40af-b7b6-5a8a9c28b1fa.png)
